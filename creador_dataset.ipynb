# %% [markdown]
# <a href="https://colab.research.google.com/github/m4tuuc/creador_dataset_OCR/blob/main/creador_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# En caso de que lo copies y lo ejecutes en tu copilador tenes que instalar lo mismo que se instala aqui, es decir en la terminal.
# Instalar tesseract https://github.com/UB-Mannheim/tesseract/wiki
# spa : https://github.com/tesseract-ocr/tessdata/blob/main/spa.traineddata

# %% [markdown]
# # Instrucciones
# 1- Nos dirigimos a esta web [Queen Seeds](https://www.royalqueenseeds.es/33-semillas-feminizadas-de-marihuana) y seleccionamos la primera cepa.
# ![Sin título.jpg](data:image/jpeg;base64,...)
#
# 2- Seleccionamos la pestaña "Ficha tecnica" que esta dentro de la cepa elegida.
# ![Sin título-1.jpg](data:image/jpeg;base64,...)
#
# 3- Copiamos la tabla que sale abajo de ficha tecnica tal cual como esta en la imagen
#
# ![30-stonefree-stand.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Ejecutamos el codigo
# Una vez que se ejecuta el codigo nos va a pedir que subamos la imagen que sacamos captura, para no guardar imagenes lo que hay que hacer es antes de ejecutar el script sacamos una captura de pantalla de la tabla en el tamaño que esta en la imagen y nos saldra una ventana como esta.
#
# ![2.jpg](data:image/jpeg;base64,...)
#
# Esto creara un archivo CSV llamado cepas.csv que se guardara en la carpeta del script, el archivo ira añadiendo una nueva cepa por cada ejecucion.
